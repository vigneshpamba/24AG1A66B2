# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshpamba/24AG1A66B2/blob/main/1stproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing pandas python library

# %%
import pandas as pd

# %% [markdown]
# importing datasets

# %%
df=pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
df.tail(10)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2994    -117.93     33.86                35.0        931.0           181.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2990      1500.0       430.0         2.6923            150000.0
# ...

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# info()-- print information  about the data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# importing text file

# %%
df2=pd.read_csv("/content/project1.txt")

# %%
df2
# Out:
# Empty DataFrame
# Columns: [EXPLORATORY DATA ANALAYSIS AND MACHINE LEARNIng]
# Index: []

# %%
df2.describe()
# Out:
#        EXPLORATORY DATA ANALAYSIS AND MACHINE LEARNIng
# count                                                0
# unique                                               0
# top                                                NaN
# freq                                               NaN

# %%
df3=pd.read_excel("/content/project1.xlsx")

# %%
df3.head()
# Out:
#          name   age sex  marks       city
# 0       kajal  38.0   f   85.0  hyderabad
# 1     mahesh   42.0   m   65.0     mumbai
# 2     prabhas   NaN   m   64.0     gadwal
# 3      kalyan  50.0   m   76.0        NaN
# 4  allu arjun  38.0   f    NaN     nirmal

# %%
df3.describe()
# Out:
#              age      marks
# count   4.000000   4.000000
# mean   42.000000  72.500000
# std     5.656854   9.949874
# min    38.000000  64.000000
# 25%    38.000000  64.750000
# 50%    40.000000  70.500000
# 75%    44.000000  78.250000
# max    50.000000  85.000000

# %%
df3.tail()
# Out:
#          name   age sex  marks       city
# 0       kajal  38.0   f   85.0  hyderabad
# 1     mahesh   42.0   m   65.0     mumbai
# 2     prabhas   NaN   m   64.0     gadwal
# 3      kalyan  50.0   m   76.0        NaN
# 4  allu arjun  38.0   f    NaN     nirmal

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     4 non-null      float64
#  2   sex     5 non-null      object
#  3   marks   4 non-null      float64
#  4   city    4 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 332.0+ bytes
